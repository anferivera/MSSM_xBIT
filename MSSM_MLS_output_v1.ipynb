# %% [markdown]
# Reading outut xBIT file

# %%
import numpy as np
import pandas as pd
import subprocess
import time

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
SPheno_output = subprocess.getoutput('cat /home/anferivera/Work/xBIT-master/Output/m0_m12_DM_CMSSM_MLS/full_SpectrumFiles')

# %%
SPheno_output.splitlines()
# Out:
# ['# SUSY Les Houches Accord 2 - MSSM Spectrum + Decays + Flavour Observables',
#  '# SPheno module generated by SARAH',
#  '# ----------------------------------------------------------------------',
#  '# SPheno v4.0.5  ',
#  '#   W. Porod, Comput. Phys. Commun. 153 (2003) 275-315, hep-ph/0301101',
#  '#   W. Porod, F.Staub, Comput.Phys.Commun.183 (2012) 2458-2469, arXiv:1104.1573',
#  '# SARAH: 4.15.1  ',
#  '#   F. Staub; arXiv:0806.0538 (online manual)',
#  '#   F. Staub; Comput. Phys. Commun. 181 (2010) 1077-1086; arXiv:0909.2863',
#  '#   F. Staub; Comput. Phys. Commun. 182 (2011)  808-833; arXiv:1002.0840',
#  '#   F. Staub; Comput. Phys. Commun. 184 (2013)  1792-1809; arXiv:1207.0906',
#  '#   F. Staub; Comput. Phys. Commun. 185 (2014)  1773-1790; arXiv:1309.7223 ',
#  '# Including the calculation of flavor observables based on FlavorKit ',
#  '#   W. Porod, F. Staub, A. Vicente; Eur.Phys.J. C74 (2014) 8, 2992; arXiv:1405.1434 ',
#  '# Two-loop mass corrections to Higgs fields based on ',
#  '#   M. D. Goodsell, K. Nickel, F. Staub; Eur.Phys.J. C75 (2015) no.6, 290; arXiv:1411.0675 ',
#  '#   M. D. Goodsell, K. Nickel, F. Staub; Eur.Phys.J. C75 (2015) no.1, 32; arXiv:1503.03098',
#  '#   M. D. Goodsell, F. Staub; Eur.Phys.J.C 77 (2017) 1, 46, arXiv:1604.05335',
#  '#   J. Braathen, M. D. Goodsell, F. Staub; Eur.Phys.J.C 77 (2017) 11, 758; arXiv:1703.09237',
#  '# Loop decays based on ',
#  '#   M. D. Goodsell, S. Liebler, F. Staub; Eur.Phys.J.C 77 (2017) 11, 757; arXiv:1706.05372',
#  '# Unitarity routines based on ',
#  '#   M. D. Goodsell, F. Staub; Eur.Phys.J.C 78 (2018) 8, 649; arXiv:1805.07306',
#  '#   M. D. Goodsell, R. Moutafis; arXiv:2012.09022',
#  '#  ',
#  '# in case of problems send email to goodsell@lpthe.jussieu.fr and porod@physik.uni-wuerzburg.de, or consult the forum/wiki ',
#  '# ----------------------------------------------------------------------',
#  '# Created: 31.12.2022,  08:36',
#  'Block SPINFO         # Program information',
#  '     1   SPhenoSARAH      # spectrum calculator',
#  '     2   v4.0.5      # version number of SPheno',
#  '     9   4.15.1      # version number of SARAH',
#  'Block MODSEL  # Input parameters',
#  '     1  1   #  GUT scale input',
#  '     2  1   #  Boundary conditions ',
#  'Block MINPAR  # Input parameters',
#  '    1    3.54600000E+02  # m0',
#  '    2    1.84000000E+03  # m12',
#  '    3    1.00000000E+01  # TanBeta',
#  '    4    1.00000000E+00  # SignumMu',
#  '    5    0.00000000E+00  # Azero',
#  'Block gaugeGUT Q=  8.19599146E+15  # (GUT scale)',
#  '   1    6.87644771E-01  # g1(Q)',
#  '   2    6.87635810E-01  # g2(Q)',
#  '   3    6.94090428E-01  # g3(Q)',
#  'Block SMINPUTS  # SM parameters',
#  '         1     1.27931992E+02  # alpha_em^-1(MZ)^MSbar',
#  '         2     1.16640000E-05  # G_mu [GeV^-2]',
#  '         3     1.18700000E-01  # alpha_s(MZ)^MSbar',
#  '         4     9.11890000E+01  # m_Z(pole)',
#  '         5     4.18000000E+00  # m_b(m_b), MSbar',
#  '         6     1.73500000E+02  # m_t(pole)',
#  '         7     1.77670000E+00  # m_tau(pole)',
#  'Block GAUGE Q=  2.93108979E+03  # (SUSY Scale)',
#  '   1    3.64725485E-01  # g1',
#  '   2    6.35277217E-01  # g2',
#  '   3    1.00666949E+00  # g3',
#  'Block HMIX Q=  2.93108979E+03  # (SUSY Scale)',
#  '   1    1.85705830E+03  # Mu',
#  ' 101    4.91628652E+05  # Bmu',
#  ' 102    2.47734043E+01  # vd',
#  ' 103    2.47734043E+02  # vu',
#  '   3    2.48969632E+02  # v',
#  '  10    1.47112767E+00  # betaH',
#  '  11   -9.99942038E-02  # alphaH',
#  'Block MSOFT Q=  2.93108979E+03  # (SUSY Scale)',
#  '  21    1.47169636E+06  # mHd2',
#  '  22   -3.40357807E+06  # mHu2',
#  '   1    8.62721297E+02  # M1',
#  '   2    1.57046193E+03  # M2',
#  '   3    3.87043279E+03  # M3',
#  'Block PHASES Q=  2.93108979E+03  # (SUSY Scale)',
#  '   1    1.00000000E+00  # pG',
#  'Block TREEHMIX Q=  2.93108979E+03  # (SUSY Scale)',
#  '   1    1.85705830E+03  # Mu',
#  ' 101    4.91628652E+05  # Bmu',
#  'Block LOOPHMIX Q=  2.93108979E+03  # (SUSY Scale)',
#  '   1    0.00000000E+00  # Mu',
#  ' 101    0.00000000E+00  # Bmu',
#  'Block Yd Q=  2.93108979E+03  # (SUSY Scale)',
#  '  1  1     1.28831474E-04   # Real(Yd(1,1),dp)',
#  '  1  2     0.00000000E+00   # Real(Yd(1,2),dp)',
#  '  1  3     0.00000000E+00   # Real(Yd(1,3),dp)',
#  '  2  1     0.00000000E+00   # Real(Yd(2,1),dp)',
#  '  2  2     2.44779736E-03   # Real(Yd(2,2),dp)',
#  '  2  3     0.00000000E+00   # Real(Yd(2,3),dp)',
#  '  3  1     0.00000000E+00   # Real(Yd(3,1),dp)',
#  '  3  2     0.00000000E+00   # Real(Yd(3,2),dp)',
#  '  3  3     1.27860248E-01   # Real(Yd(3,3),dp)',
#  'Block Ye Q=  2.93108979E+03  # (SUSY Scale)',
#  '  1  1     2.99324112E-05   # Real(Ye(1,1),dp)',
#  '  1  2     0.00000000E+00   # Real(Ye(1,2),dp)',
#  '  1  3     0.00000000E+00   # Real(Ye(1,3),dp)',
#  '  2  1     0.00000000E+00   # Real(Ye(2,1),dp)',
#  '  2  2     6.18907600E-03   # Real(Ye(2,2),dp)',
#  '  2  3     0.00000000E+00   # Real(Ye(2,3),dp)',
#  '  3  1     0.00000000E+00   # Real(Ye(3,1),dp)',
#  '  3  2     0.00000000E+00   # Real(Ye(3,2),dp)',
#  '  3  3     1.04085602E-01   # Real(Ye(3,3),dp)',
#  'Block Yu Q=  2.93108979E+03  # (SUSY Scale)',
#  '  1  1     6.64165257E-06   # Real(Yu(1,1),dp)',
#  '  1  2     0.00000000E+00   # Real(Yu(1,2),dp)',
#  '  1  3     0.00000000E+00   # Real(Yu(1,3),dp)',
#  '  2  1     0.00000000E+00   # Real(Yu(2,1),dp)',
#  '  2  2     3.37395981E-03   # Real(Yu(2,2),dp)',
#  '  2  3     0.00000000E+00   # Real(Yu(2,3),dp)',
#  '  3  1     0.00000000E+00   # Real(Yu(3,1),dp)',
#  '  3  2     0.00000000E+00   # Real(Yu(3,2),dp)',
#  '  3  3     8.22105921E-01   # Real(Yu(3,3),dp)',
#  'Block Td Q=  2.93108979E+03  # (SUSY Scale)',
#  '  1  1    -5.75441365E-01   # Real(Td(1,1),dp)',
#  '  1  2     0.00000000E+00   # Real(Td(1,2),dp)',
#  '  1  3     0.00000000E+00   # Real(Td(1,3),dp)',
#  '  2  1     0.00000000E+00   # Real(Td(2,1),dp)',
#  '  2  2    -1.09333553E+01   # Real(Td(2,2),dp)',
#  '  2  3     0.00000000E+00   # Real(Td(2,3),dp)',
#  '  3  1     0.00000000E+00   # Real(Td(3,1),dp)',
#  '  3  2     0.00000000E+00   # Real(Td(3,2),dp)',
#  '  3  3    -5.35133431E+02   # Real(Td(3,3),dp)',
#  'Block Te Q=  2.93108979E+03  # (SUSY Scale)',
#  '  1  1    -3.15605494E-02   # Real(Te(1,1),dp)',
#  '  1  2     0.00000000E+00   # Real(Te(1,2),dp)',
#  '  1  3     0.00000000E+00   # Real(Te(1,3),dp)',
#  '  2  1     0.00000000E+00   # Real(Te(2,1),dp)',
#  '  2  2    -6.52559995E+00   # Real(Te(2,2),dp)',
#  '  2  3     0.00000000E+00   # Real(Te(2,3),dp)',
#  '  3  1     0.00000000E+00   # Real(Te(3,1),dp)',
#  '  3  2     0.00000000E+00   # Real(Te(3,2),dp)',
#  '  3  3    -1.09159559E+02   # Real(Te(3,3),dp)',
#  'Block Tu Q=  2.93108979E+03  # (SUSY Scale)',
#  '  1  1    -2.49672244E-02   # Real(Tu(1,1),dp)',
#  '  1  2     0.00000000E+00   # Real(Tu(1,2),dp)',
#  '  1  3     0.00000000E+00   # Real(Tu(1,3),dp)',
#  '  2  1     0.00000000E+00   # Real(Tu(2,1),dp)',
#  '  2  2    -1.26832986E+01   # Real(Tu(2,2),dp)',
#  '  2  3     0.00000000E+00   # Real(Tu(2,3),dp)',
#  '  3  1     0.00000000E+00   # Real(Tu(3,1),dp)',
#  '  3  2     0.00000000E+00   # Real(Tu(3,2),dp)',
#  '  3  3    -2.43795858E+03   # Real(Tu(3,3),dp)',
#  'Block MSQ2 Q=  2.93108979E+03  # (SUSY Scale)',
#  '  1  1     1.18243042E+07   # Real(mq2(1,1),dp)',
#  '  1  2     0.00000000E+00   # Real(mq2(1,2),dp)',
#  '  1  3     0.00000000E+00   # Real(mq2(1,3),dp)',
#  '  2  1     0.00000000E+00   # Real(mq2(2,1),dp)',
#  '  2  2     1.18242543E+07   # Real(mq2(2,2),dp)',
#  '  2  3     0.00000000E+00   # Real(mq2(2,3),dp)',
#  '  3  1     0.00000000E+00   # Real(mq2(3,1),dp)',
#  '  3  2     0.00000000E+00   # Real(mq2(3,2),dp)',
#  '  3  3     1.01002094E+07   # Real(mq2(3,3),dp)',
#  'Block MSL2 Q=  2.93108979E+03  # (SUSY Scale)',
#  '  1  1     1.62467497E+06   # Real(ml2(1,1),dp)',
#  '  1  2     0.00000000E+00   # Real(ml2(1,2),dp)',
#  '  1  3     0.00000000E+00   # Real(ml2(1,3),dp)',
#  '  2  1     0.00000000E+00   # Real(ml2(2,1),dp)',
#  '  2  2     1.62464394E+06   # Real(ml2(2,2),dp)',
#  '  2  3     0.00000000E+00   # Real(ml2(2,3),dp)',
#  '  3  1     0.00000000E+00   # Real(ml2(3,1),dp)',
#  '  3  2     0.00000000E+00   # Real(ml2(3,2),dp)',
#  '  3  3     1.61590912E+06   # Real(ml2(3,3),dp)',
#  'Block MSD2 Q=  2.93108979E+03  # (SUSY Scale)',
#  '  1  1     1.04854501E+07   # Real(md2(1,1),dp)',
#  '  1  2     0.00000000E+00   # Real(md2(1,2),dp)',
#  '  1  3     0.00000000E+00   # Real(md2(1,3),dp)',
#  '  2  1     0.00000000E+00   # Real(md2(2,1),dp)',
#  '  2  2     1.04854137E+07   # Real(md2(2,2),dp)',
#  '  2  3     0.00000000E+00   # Real(md2(2,3),dp)',
#  '  3  1     0.00000000E+00   # Real(md2(3,1),dp)',
#  '  3  2     0.00000000E+00   # Real(md2(3,2),dp)',
#  '  3  3     1.03893657E+07   # Real(md2(3,3),dp)',
#  'Block MSU2 Q=  2.93108979E+03  # (SUSY Scale)',
#  '  1  1     1.06455300E+07   # Real(mu2(1,1),dp)',
#  '  1  2     0.00000000E+00   # Real(mu2(1,2),dp)',
#  '  1  3     0.00000000E+00   # Real(mu2(1,3),dp)',
#  '  2  1     0.00000000E+00   # Real(mu2(2,1),dp)',
#  '  2  2     1.06454665E+07   # Real(mu2(2,2),dp)',
#  '  2  3     0.00000000E+00   # Real(mu2(2,3),dp)',
#  '  3  1     0.00000000E+00   # Real(mu2(3,1),dp)',
#  '  3  2     0.00000000E+00   # Real(mu2(3,2),dp)',
#  '  3  3     7.29342479E+06   # Real(mu2(3,3),dp)',
#  'Block MSE2 Q=  2.93108979E+03  # (SUSY Scale)',
#  '  1  1     6.05980490E+05   # Real(me2(1,1),dp)',
#  '  1  2     0.00000000E+00   # Real(me2(1,2),dp)',
#  '  1  3     0.00000000E+00   # Real(me2(1,3),dp)',
#  '  2  1     0.00000000E+00   # Real(me2(2,1),dp)',
#  '  2  2     6.05918430E+05   # Real(me2(2,2),dp)',
#  '  2  3     0.00000000E+00   # Real(me2(2,3),dp)',
#  '  3  1     0.00000000E+00   # Real(me2(3,1),dp)',
#  '  3  2     0.00000000E+00   # Real(me2(3,2),dp)',
#  '  3  3     5.88448795E+05   # Real(me2(3,3),dp)',
#  'Block MASS  # Mass spectrum',
#  '#   PDG code      mass          particle',
#  '   1000001     3.17723418E+03  # Sd_1',
#  '   1000003     3.22472378E+03  # Sd_2',
#  '   1000005     3.23822274E+03  # Sd_3',
#  '   2000001     3.23822847E+03  # Sd_4',
#  '   2000003     3.43913606E+03  # Sd_5',
#  '   2000005     3.43914322E+03  # Sd_6',
#  '   1000002     2.69095402E+03  # Su_1',
#  '   1000004     3.19214726E+03  # Su_2',
#  '   1000006     3.26253202E+03  # Su_3',
#  '   2000002     3.26254240E+03  # Su_4',
#  '   2000004     3.43824532E+03  # Su_5',
#  '   2000006     3.43825186E+03  # Su_6',
#  '   1000011     7.67612409E+02  # Se_1',
#  '   1000013     7.79701604E+02  # Se_2',
#  '   1000015     7.79744242E+02  # Se_3',
#  '   2000011     1.27248227E+03  # Se_4',
#  '   2000013     1.27542275E+03  # Se_5',
#  '   2000015     1.27543317E+03  # Se_6',
#  '   1000012     1.26958014E+03  # Sv_1',
#  '   1000014     1.27301554E+03  # Sv_2',
#  '   1000016     1.27302772E+03  # Sv_3',
#  '        25     8.93803379E+01  # hh_1',
#  '        35     2.22840211E+03  # hh_2',
#  '        36     2.22832883E+03  # Ah_2',
#  '        37     2.22973169E+03  # Hpm_2',
#  '        23     9.11890000E+01  # VZ',
#  '        24     8.03572623E+01  # VWm',
#  '         1     2.25679790E-03  # Fd_1',
#  '         3     4.28791487E-02  # Fd_2',
#  '         5     4.18000000E+00  # Fd_3',
#  '         2     1.16344765E-03  # Fu_1',
#  '         4     5.91031458E-01  # Fu_2',
#  '         6     1.73500000E+02  # Fu_3',
#  '        11     5.24339281E-04  # Fe_1',
#  '        13     1.08416781E-01  # Fe_2',
#  '        15     1.77670000E+00  # Fe_3',
#  '   1000021     3.87043279E+03  # Glu',
#  '   1000022     8.61780889E+02  # Chi_1',
#  '   1000023     1.55870559E+03  # Chi_2',
#  '   1000025    -1.85809399E+03  # Chi_3',
#  '   1000035     1.87079074E+03  # Chi_4',
#  '   1000024     1.55866932E+03  # Cha_1',
#  '   1000037     1.87031393E+03  # Cha_2',
#  'Block LSP  # LSP and NLSP',
#  '  1   1000011   # LSP ',
#  '  2   1000013   # NLSP ',
#  'Block DSQMIX Q=  2.93108979E+03  # ()',
#  '  1  1     0.00000000E+00   # Real(ZD(1,1),dp)',
#  '  1  2     0.00000000E+00   # Real(ZD(1,2),dp)',
#  '  1  3     9.85422629E-01   # Real(ZD(1,3),dp)',
#  '  1  4     0.00000000E+00   # Real(ZD(1,4),dp)',
#  '  1  5     0.00000000E+00   # Real(ZD(1,5),dp)',
#  '  1  6     1.70124197E-01   # Real(ZD(1,6),dp)',
#  '  2  1     0.00000000E+00   # Real(ZD(2,1),dp)',
#  '  2  2     0.00000000E+00   # Real(ZD(2,2),dp)',
#  '  2  3    -1.70124197E-01   # Real(ZD(2,3),dp)',
#  '  2  4     0.00000000E+00   # Real(ZD(2,4),dp)',
#  '  2  5     0.00000000E+00   # Real(ZD(2,5),dp)',
#  '  2  6     9.85422629E-01   # Real(ZD(2,6),dp)',
#  '  3  1     0.00000000E+00   # Real(ZD(3,1),dp)',
#  '  3  2     7.36312851E-04   # Real(ZD(3,2),dp)',
#  '  3  3     0.00000000E+00   # Real(ZD(3,3),dp)',
#  '  3  4     0.00000000E+00   # Real(ZD(3,4),dp)',
#  '  3  5     9.99999729E-01   # Real(ZD(3,5),dp)',
#  '  3  6     0.00000000E+00   # Real(ZD(3,6),dp)',
#  '  4  1    -3.87529781E-05   # Real(ZD(4,1),dp)',
#  '  4  2    -0.00000000E+00   # Real(ZD(4,2),dp)',
#  '  4  3    -0.00000000E+00   # Real(ZD(4,3),dp)',
#  '  4  4    -9.99999999E-01   # Real(ZD(4,4),dp)',
#  '  4  5    -0.00000000E+00   # Real(ZD(4,5),dp)',
#  '  4  6    -0.00000000E+00   # Real(ZD(4,6),dp)',
#  '  5  1     0.00000000E+00   # Real(ZD(5,1),dp)',
#  '  5  2     9.99999729E-01   # Real(ZD(5,2),dp)',
#  '  5  3     0.00000000E+00   # Real(ZD(5,3),dp)',
#  '  5  4     0.00000000E+00   # Real(ZD(5,4),dp)',
#  '  5  5    -7.36312851E-04   # Real(ZD(5,5),dp)',
#  '  5  6     0.00000000E+00   # Real(ZD(5,6),dp)',
#  '  6  1    -9.99999999E-01   # Real(ZD(6,1),dp)',
#  '  6  2     0.00000000E+00   # Real(ZD(6,2),dp)',
#  '  6  3     0.00000000E+00   # Real(ZD(6,3),dp)',
#  '  6  4     3.87529781E-05   # Real(ZD(6,4),dp)',
#  '  6  5     0.00000000E+00   # Real(ZD(6,5),dp)',
#  '  6  6     0.00000000E+00   # Real(ZD(6,6),dp)',
#  'Block SNUMIX Q=  2.93108979E+03  # ()',
#  '  1  1     0.00000000E+00   # Real(ZV(1,1),dp)',
#  '  1  2     0.00000000E+00   # Real(ZV(1,2),dp)',
#  '  1  3     1.00000000E+00   # Real(ZV(1,3),dp)',
#  '  2  1     0.00000000E+00   # Real(ZV(2,1),dp)',
#  '  2  2     1.00000000E+00   # Real(ZV(2,2),dp)',
#  '  2  3     0.00000000E+00   # Real(ZV(2,3),dp)',
#  '  3  1     1.00000000E+00   # Real(ZV(3,1),dp)',
#  '  3  2     0.00000000E+00   # Real(ZV(3,2),dp)',
#  '  3  3     0.00000000E+00   # Real(ZV(3,3),dp)',
#  'Block USQMIX Q=  2.93108979E+03  # ()',
#  '  1  1    -0.00000000E+00   # Real(ZU(1,1),dp)',
#  '  1  2    -0.00000000E+00   # Real(ZU(1,2),dp)',
#  '  1  3    -1.55812074E-01   # Real(ZU(1,3),dp)',
#  '  1  4    -0.00000000E+00   # Real(ZU(1,4),dp)',
#  '  1  5    -0.00000000E+00   # Real(ZU(1,5),dp)',
#  '  1  6    -9.87786717E-01   # Real(ZU(1,6),dp)',
#  '  2  1     0.00000000E+00   # Real(ZU(2,1),dp)',
#  '  2  2     0.00000000E+00   # Real(ZU(2,2),dp)',
#  '  2  3    -9.87786717E-01   # Real(ZU(2,3),dp)',
#  '  2  4     0.00000000E+00   # Real(ZU(2,4),dp)',
#  '  2  5     0.00000000E+00   # Real(ZU(2,5),dp)',
#  '  2  6     1.55812074E-01   # Real(ZU(2,6),dp)',
#  '  3  1     0.00000000E+00   # Real(ZU(3,1),dp)',
#  '  3  2     1.98022844E-03   # Real(ZU(3,2),dp)',
#  '  3  3     0.00000000E+00   # Real(ZU(3,3),dp)',
#  '  3  4     0.00000000E+00   # Real(ZU(3,4),dp)',
#  '  3  5     9.99998039E-01   # Real(ZU(3,5),dp)',
#  '  3  6     0.00000000E+00   # Real(ZU(3,6),dp)',
#  '  4  1    -3.89817022E-06   # Real(ZU(4,1),dp)',
#  '  4  2    -0.00000000E+00   # Real(ZU(4,2),dp)',
#  '  4  3    -0.00000000E+00   # Real(ZU(4,3),dp)',
#  '  4  4    -1.00000000E+00   # Real(ZU(4,4),dp)',
#  '  4  5    -0.00000000E+00   # Real(ZU(4,5),dp)',
#  '  4  6    -0.00000000E+00   # Real(ZU(4,6),dp)',
#  '  5  1     0.00000000E+00   # Real(ZU(5,1),dp)',
#  '  5  2     9.99998039E-01   # Real(ZU(5,2),dp)',
#  '  5  3     0.00000000E+00   # Real(ZU(5,3),dp)',
#  '  5  4     0.00000000E+00   # Real(ZU(5,4),dp)',
#  '  5  5    -1.98022844E-03   # Real(ZU(5,5),dp)',
#  '  5  6     0.00000000E+00   # Real(ZU(5,6),dp)',
#  '  6  1    -1.00000000E+00   # Real(ZU(6,1),dp)',
#  '  6  2     0.00000000E+00   # Real(ZU(6,2),dp)',
#  '  6  3     0.00000000E+00   # Real(ZU(6,3),dp)',
#  '  6  4     3.89817022E-06   # Real(ZU(6,4),dp)',
#  '  6  5     0.00000000E+00   # Real(ZU(6,5),dp)',
#  '  6  6     0.00000000E+00   # Real(ZU(6,6),dp)',
#  'Block SELMIX Q=  2.93108979E+03  # ()',
#  '  1  1    -0.00000000E+00   # Real(ZE(1,1),dp)',
#  '  1  2    -0.00000000E+00   # Real(ZE(1,2),dp)',
#  '  1  3    -3.47518698E-02   # Real(ZE(1,3),dp)',
#  '  1  4    -0.00000000E+00   # Real(ZE(1,4),dp)',
#  '  1  5    -0.00000000E+00   # Real(ZE(1,5),dp)',
#  '  1  6    -9.99395971E-01   # Real(ZE(1,6),dp)',
#  '  2  1     0.00000000E+00   # Real(ZE(2,1),dp)',
#  '  2  2     2.08848143E-03   # Real(ZE(2,2),dp)',
#  '  2  3     0.00000000E+00   # Real(ZE(2,3),dp)',
#  '  2  4     0.00000000E+00   # Real(ZE(2,4),dp)',
#  '  2  5     9.99997819E-01   # Real(ZE(2,5),dp)',
#  '  2  6     0.00000000E+00   # Real(ZE(2,6),dp)',
#  '  3  1    -1.01009685E-05   # Real(ZE(3,1),dp)',
#  '  3  2    -0.00000000E+00   # Real(ZE(3,2),dp)',
#  '  3  3    -0.00000000E+00   # Real(ZE(3,3),dp)',
#  '  3  4    -1.00000000E+00   # Real(ZE(3,4),dp)',
#  '  3  5    -0.00000000E+00   # Real(ZE(3,5),dp)',
#  '  3  6    -0.00000000E+00   # Real(ZE(3,6),dp)',
#  '  4  1     0.00000000E+00   # Real(ZE(4,1),dp)',
#  '  4  2     0.00000000E+00   # Real(ZE(4,2),dp)',
#  '  4  3    -9.99395971E-01   # Real(ZE(4,3),dp)',
#  '  4  4     0.00000000E+00   # Real(ZE(4,4),dp)',
#  '  4  5     0.00000000E+00   # Real(ZE(4,5),dp)',
#  '  4  6     3.47518698E-02   # Real(ZE(4,6),dp)',
#  '  5  1     0.00000000E+00   # Real(ZE(5,1),dp)',
#  '  5  2     9.99997819E-01   # Real(ZE(5,2),dp)',
#  '  5  3     0.00000000E+00   # Real(ZE(5,3),dp)',
#  '  5  4     0.00000000E+00   # Real(ZE(5,4),dp)',
#  '  5  5    -2.08848143E-03   # Real(ZE(5,5),dp)',
#  '  5  6     0.00000000E+00   # Real(ZE(5,6),dp)',
#  '  6  1    -1.00000000E+00   # Real(ZE(6,1),dp)',
#  '  6  2     0.00000000E+00   # Real(ZE(6,2),dp)',
#  '  6  3     0.00000000E+00   # Real(ZE(6,3),dp)',
#  '  6  4     1.01009685E-05   # Real(ZE(6,4),dp)',
#  '  6  5     0.00000000E+00   # Real(ZE(6,5),dp)',
#  '  6  6     0.00000000E+00   # Real(ZE(6,6),dp)',
#  'Block SCALARMIX Q=  2.93108979E+03  # ()',
#  '  1  1    -9.98276494E-02   # ZH(1,1)',
#  '  1  2    -9.95004744E-01   # ZH(1,2)',
#  '  2  1    -9.95004744E-01   # ZH(2,1)',
#  '  2  2     9.98276494E-02   # ZH(2,2)',
#  'Block PSEUDOSCALARMIX Q=  2.93108979E+03  # ()',
#  '  1  1     9.95037190E-02   # ZA(1,1)',
#  '  1  2    -9.95037190E-01   # ZA(1,2)',
#  '  2  1    -9.95037190E-01   # ZA(2,1)',
#  '  2  2    -9.95037190E-02   # ZA(2,2)',
#  'Block CHARGEMIX Q=  2.93108979E+03  # ()',
#  '  1  1     9.95037190E-02   # ZP(1,1)',
#  '  1  2    -9.95037190E-01   # ZP(1,2)',
#  '  2  1    -9.95037190E-01   # ZP(2,1)',
#  '  2  2    -9.95037190E-02   # ZP(2,2)',
#  'Block NMIX Q=  2.93108979E+03  # ()',
#  '  1  1    -9.99313369E-01   # Real(ZN(1,1),dp)',
#  '  1  2     2.30974573E-03   # Real(ZN(1,2),dp)',
#  '  1  3    -3.25511525E-02   # Real(ZN(1,3),dp)',
#  '  1  4     1.75464499E-02   # Real(ZN(1,4),dp)',
#  '  2  1    -9.50073836E-03   # Real(ZN(2,1),dp)',
#  '  2  2    -9.79674497E-01   # Real(ZN(2,2),dp)',
#  '  2  3     1.51421164E-01   # Real(ZN(2,3),dp)',
#  '  2  4    -1.31222127E-01   # Real(ZN(2,4),dp)',
#  '  3  1    -1.05696458E-02   # Real(ZN(3,1),dp)',
#  '  3  2     1.46098388E-02   # Real(ZN(3,2),dp)',
#  '  3  3     7.06750880E-01   # Real(ZN(3,3),dp)',
#  '  3  4     7.07232656E-01   # Real(ZN(3,4),dp)',
#  '  4  1    -3.42170852E-02   # Real(ZN(4,1),dp)',
#  '  4  2     2.00047737E-01   # Real(ZN(4,2),dp)',
#  '  4  3     6.90300839E-01   # Real(ZN(4,3),dp)',
#  '  4  4    -6.94474511E-01   # Real(ZN(4,4),dp)',
#  'Block UMIX Q=  2.93108979E+03  # ()',
#  '  1  1     9.76667865E-01   # Real(UM(1,1),dp)',
#  '  1  2    -2.14755400E-01   # Real(UM(1,2),dp)',
#  '  2  1     2.14755400E-01   # Real(UM(2,1),dp)',
#  '  2  2     9.76667865E-01   # Real(UM(2,2),dp)',
#  'Block VMIX Q=  2.93108979E+03  # ()',
#  '  1  1     9.82523867E-01   # Real(UP(1,1),dp)',
#  '  1  2    -1.86136646E-01   # Real(UP(1,2),dp)',
#  '  2  1     1.86136646E-01   # Real(UP(2,1),dp)',
#  '  2  2     9.82523867E-01   # Real(UP(2,2),dp)',
#  'Block UELMIX Q=  2.93108979E+03  # ()',
#  '  1  1     1.00000000E+00   # Real(ZEL(1,1),dp)',
#  '  1  2     0.00000000E+00   # Real(ZEL(1,2),dp)',
#  '  1  3     0.00000000E+00   # Real(ZEL(1,3),dp)',
#  '  2  1     0.00000000E+00   # Real(ZEL(2,1),dp)',
#  '  2  2     1.00000000E+00   # Real(ZEL(2,2),dp)',
#  '  2  3     0.00000000E+00   # Real(ZEL(2,3),dp)',
#  '  3  1     0.00000000E+00   # Real(ZEL(3,1),dp)',
#  '  3  2     0.00000000E+00   # Real(ZEL(3,2),dp)',
#  '  3  3     1.00000000E+00   # Real(ZEL(3,3),dp)',
#  'Block UERMIX Q=  2.93108979E+03  # ()',
#  '  1  1     1.00000000E+00   # Real(ZER(1,1),dp)',
#  '  1  2     0.00000000E+00   # Real(ZER(1,2),dp)',
#  '  1  3     0.00000000E+00   # Real(ZER(1,3),dp)',
#  '  2  1     0.00000000E+00   # Real(ZER(2,1),dp)',
#  '  2  2     1.00000000E+00   # Real(ZER(2,2),dp)',
#  '  2  3     0.00000000E+00   # Real(ZER(2,3),dp)',
#  '  3  1     0.00000000E+00   # Real(ZER(3,1),dp)',
#  '  3  2     0.00000000E+00   # Real(ZER(3,2),dp)',
#  '  3  3     1.00000000E+00   # Real(ZER(3,3),dp)',
#  'Block UDLMIX Q=  2.93108979E+03  # ()',
#  '  1  1     1.00000000E+00   # Real(ZDL(1,1),dp)',
#  '  1  2     0.00000000E+00   # Real(ZDL(1,2),dp)',
#  '  1  3     0.00000000E+00   # Real(ZDL(1,3),dp)',
#  '  2  1     0.00000000E+00   # Real(ZDL(2,1),dp)',
#  '  2  2     1.00000000E+00   # Real(ZDL(2,2),dp)',
#  '  2  3     0.00000000E+00   # Real(ZDL(2,3),dp)',
#  '  3  1     0.00000000E+00   # Real(ZDL(3,1),dp)',
#  '  3  2     0.00000000E+00   # Real(ZDL(3,2),dp)',
#  '  3  3     1.00000000E+00   # Real(ZDL(3,3),dp)',
#  'Block UDRMIX Q=  2.93108979E+03  # ()',
#  '  1  1     1.00000000E+00   # Real(ZDR(1,1),dp)',
#  '  1  2     0.00000000E+00   # Real(ZDR(1,2),dp)',
#  '  1  3     0.00000000E+00   # Real(ZDR(1,3),dp)',
#  '  2  1     0.00000000E+00   # Real(ZDR(2,1),dp)',
#  '  2  2     1.00000000E+00   # Real(ZDR(2,2),dp)',
#  '  2  3     0.00000000E+00   # Real(ZDR(2,3),dp)',
#  '  3  1     0.00000000E+00   # Real(ZDR(3,1),dp)',
#  '  3  2     0.00000000E+00   # Real(ZDR(3,2),dp)',
#  '  3  3     1.00000000E+00   # Real(ZDR(3,3),dp)',
#  'Block UULMIX Q=  2.93108979E+03  # ()',
#  '  1  1     1.00000000E+00   # Real(ZUL(1,1),dp)',
#  '  1  2     0.00000000E+00   # Real(ZUL(1,2),dp)',
#  '  1  3     0.00000000E+00   # Real(ZUL(1,3),dp)',
#  '  2  1     0.00000000E+00   # Real(ZUL(2,1),dp)',
#  '  2  2     1.00000000E+00   # Real(ZUL(2,2),dp)',
#  '  2  3     0.00000000E+00   # Real(ZUL(2,3),dp)',
#  '  3  1     0.00000000E+00   # Real(ZUL(3,1),dp)',
#  '  3  2     0.00000000E+00   # Real(ZUL(3,2),dp)',
#  '  3  3     1.00000000E+00   # Real(ZUL(3,3),dp)',
#  'Block UURMIX Q=  2.93108979E+03  # ()',
#  '  1  1     1.00000000E+00   # Real(ZUR(1,1),dp)',
#  '  1  2     0.00000000E+00   # Real(ZUR(1,2),dp)',
#  '  1  3     0.00000000E+00   # Real(ZUR(1,3),dp)',
#  '  2  1     0.00000000E+00   # Real(ZUR(2,1),dp)',
#  '  2  2     1.00000000E+00   # Real(ZUR(2,2),dp)',
#  '  2  3     0.00000000E+00   # Real(ZUR(2,3),dp)',
#  '  3  1     0.00000000E+00   # Real(ZUR(3,1),dp)',
#  '  3  2     0.00000000E+00   # Real(ZUR(3,2),dp)',
#  '  3  3     1.00000000E+00   # Real(ZUR(3,3),dp)',
#  'Block SPheno # SPheno internal parameters ',
#  '         1    -1.00000000E+00  # ErrorLevel',
#  '         2     0.00000000E+00  # SPA_conventions',
#  '        11     1.00000000E+00  # Branching ratios',
#  '        13     1.00000000E+00  # 3 Body decays',
#  '        31     8.19599146E+15  # GUT scale',
#  '        33     2.93108979E+03  # Renormalization scale',
#  '        34     1.00000000E-04  # Precision',
#  '        35     4.00000000E+01  # Iterations',
#  '        38     1.00000000E+00  # RGE level',
#  '        40     7.29735257E-03  # Alpha',
#  '        41     2.49520000E+00  # Gamma_Z',
#  '        42     2.06000000E+00  # Gamma_W',
#  '        50     0.00000000E+00  # Rotate negative fermion masses',
#  '        51     0.00000000E+00  # Switch to SCKM matrix',
#  '        52     1.00000000E+00  # Ignore negative masses',
#  '        53     0.00000000E+00  # Ignore negative masses at MZ',
#  '        55     0.00000000E+00  # Calculate one loop masses',
#  '        56     0.00000000E+00  # Calculate two-loop Higgs masses',
#  '        57     1.00000000E+00  # Calculate low energy',
#  '        60     1.00000000E+00  # Include kinetic mixing',
#  '        65     1.00000000E+00  # Solution of tadpole equation',
#  '         8     3.00000000E+00  # Two-Loop Method: diagrammatic ',
#  '         9     1.00000000E+00  # Gauge-less limit',
#  '       400     1.00000000E-01  # Step-size for purely-numerical methode for 2-loop calculation',
#  '       401     1.00000000E-03  # Step-size for semi-analytical methode for 2-loop calculation',
#  '       410     0.00000000E+00  # indicative error in numerical derivation',
#  'Block HiggsLHC7 # Higgs production cross section at LHC7 [pb] (rescaled SM values from HXSWG) ',
#  '  1        25        3.09294010E+01 # Gluon fusion ',
#  '  2        25        1.72839931E+00 # Vector boson fusion ',
#  '  3        25        1.66441412E+00 # W-H production ',
#  '  4        25        8.77564211E-01 # Z-H production ',
#  '  5        25        2.19793125E-01 # t-t-H production ',
#  'Block HiggsLHC8 # Higgs production cross section at LHC8 [pb] (rescaled SM values from HXSWG) ',
#  '  1        25        3.87396452E+01 # Gluon fusion ',
#  '  2        25        2.18940023E+00 # Vector boson fusion ',
#  '  3        25        2.01409835E+00 # W-H production ',
#  '  4        25        1.07913221E+00 # Z-H production ',
#  '  5        25        3.29092247E-01 # t-t-H production ',
#  'Block HiggsLHC13 # Higgs production cross section at LHC13 [pb] (rescaled SM values from SusHI 1.5.0) ',
#  '  1        25        8.52899607E+01 # Gluon fusion ',
#  'Block HiggsLHC14 # Higgs production cross section at LHC14 [pb] (rescaled SM values from SusHI 1.5.0)',
#  '  1        25        9.52634333E+01 # Gluon fusion ',
#  'Block HiggsFCC100 # Higgs production cross section at FCC-pp [pb] (rescaled SM values from SusHI 1.5.0)',
#  '  1        25        1.19070317E+03 # Gluon fusion ',
#  'Block HiggsCouplingsFermions # ',
#  '    1.00325546E+00    0.00000000E+00        3             25         5         5 # h_1 b b coupling ',
#  '    1.00325546E+00    0.00000000E+00        3             25         3         3 # h_1 s s coupling ',
#  '    9.99967392E-01    0.00000000E+00        3             25         6         6 # h_1 t t coupling  ',
#  '    9.99967392E-01    0.00000000E+00        3             25         4         4 # h_1 c c coupling ',
#  '    1.00325546E+00    0.00000000E+00        3             25        15        15 # h_1 tau tau coupling ',
#  '    1.00325546E+00    0.00000000E+00        3             25        13        13 # h_1 mu mu coupling  ',
#  '    9.99967392E+00    0.00000000E+00        3             35         5         5 # h_2 b b coupling ',
#  '    9.99967392E+00    0.00000000E+00        3             35         3         3 # h_2 s s coupling ',
#  '    1.00325546E-01    0.00000000E+00        3             35         6         6 # h_2 t t coupling  ',
#  '    1.00325546E-01    0.00000000E+00        3             35         4         4 # h_2 c c coupling ',
#  '    9.99967392E+00    0.00000000E+00        3             35        15        15 # h_2 tau tau coupling ',
#  '    9.99967392E+00    0.00000000E+00        3             35        13        13 # h_2 mu mu coupling  ',
#  '    0.00000000E+00    1.00000000E+01        3             36         5         5 # A_2 b b coupling ',
#  '    0.00000000E+00    1.00000000E+01        3             36         3         3 # A_2 s s coupling ',
#  '    0.00000000E+00    1.00000000E-01        3             36         6         6 # A_2 t t coupling ',
#  '    0.00000000E+00    1.00000000E-01        3             36         4         4 # A_2 c c coupling ',
#  '    0.00000000E+00    1.00000000E+01        3             36        15        15 # A_2 tau tau coupling ',
#  '    0.00000000E+00    1.00000000E+01        3             36        13        13 # A_2 mu mu coupling ',
#  'Block HiggsCouplingsBosons # ',
#  '    9.99999947E-01        3             25        24        24 # h_1 W W coupling ',
#  '    9.99999947E-01        3             25        23        23 # h_1 Z Z coupling  ',
#  '    0.00000000E+00        3             25        23        22 # h_1 Z gamma coupling ',
#  '    1.34143615E+00        3             25        22        22 # h_1 gamma gamma coupling ',
#  '    1.03822763E+00        3             25        21        21 # h_1 g g coupling ',
#  '    0.00000000E+00        4             25        21        21        23 # h_1 g g Z coupling ',
#  '    3.25551347E-04        3             35        24        24 # h_2 W W coupling ',
#  '    3.25551347E-04        3             35        23        23 # h_2 Z Z coupling  ',
#  '    0.00000000E+00        3             35        23        22 # h_2 Z gamma coupling ',
#  '    1.93901238E-02        3             35        22        22 # h_2 gamma gamma coupling ',
#  '    6.87064548E-02        3             35        21        21 # h_2 g g coupling ',
#  '    0.00000000E+00        4             35        21        21        23 # h_2 g g Z coupling ',
#  '    0.00000000E+00        3             36        24        24 # A_2 W W coupling ',
#  '    0.00000000E+00        3             36        23        23 # A_2 Z Z coupling ',
#  '    0.00000000E+00        3             36        23        22 # A_2 Z gamma coupling ',
#  '    1.53759887E-02        3             36        22        22 # A_2 gamma gamma coupling ',
#  '    9.92276629E-02        3             36        21        21 # A_2 g g coupling ',
#  '    0.00000000E+00        4             36        21        21        23 # A_2 g g Z coupling ',
#  '    0.00000000E+00        3             25        25        23 # h_1 h_1 Z coupling  ',
#  '    0.00000000E+00        3             25        35        23 # h_1 h_2 Z coupling  ',
#  '    1.05983679E-07        3             25        36        23 # h_1 A_2 Z coupling ',
#  '    0.00000000E+00        3             35        25        23 # h_2 h_1 Z coupling  ',
#  '    0.00000000E+00        3             35        35        23 # h_2 h_2 Z coupling  ',
#  '    9.99999894E-01        3             35        36        23 # h_2 A_2 Z coupling ',
#  '    0.00000000E+00        3             36        36        23 # A_2 A_2 Z coupling ',
#  'Block EFFHIGGSCOUPLINGS # values of loop-induced couplings ',
#  '        25           22           22     0.37608321E-04 # H-Photon-Photon ',
#  '        25           21           21     0.68638789E-04 # H-Gluon-Gluon ',
#  '        25           22           23     0.00000000E+00 # H-Photon-Z (not yet calculated by SPheno) ',
#  '        35           22           22     0.18188098E-06 # H-Photon-Photon ',
#  '        35           21           21     0.92566967E-06 # H-Gluon-Gluon ',
#  '        35           22           23     0.00000000E+00 # H-Photon-Z (not yet calculated by SPheno) ',
#  '        36           22           22     0.20318553E-06 # A-Photon-Photon ',
#  '        36           21           21     0.13451056E-05 # A-Gluon-Gluon ',
#  '        36           22           23     0.00000000E+00 # A-Photon-Z (not yet calculated by SPheno) ',
#  'Block SPhenoLowEnergy # low energy observables ',
#  '       1    9.98734732E-04  # T-parameter (1-loop BSM)',
#  '       2    3.17659558E-05  # S-parameter (1-loop BSM)',
#  '       3    1.04092609E-04  # U-parameter (1-loop BSM)',
#  '      20    1.51271435E-15  # (g-2)_e',
#  '      21    6.47148552E-11  # (g-2)_mu',
#  '      22    2.01870753E-08  # (g-2)_tau',
#  '      23    0.00000000E+00  # EDM(e)',
#  '      24    0.00000000E+00  # EDM(mu)',
#  '      25    0.00000000E+00  # EDM(tau)',
#  '      39   -2.47401613E-04  # delta(rho)',
#  'Block FlavorKitQFV # quark flavor violating observables ',
#  '     200    3.19227797E-04  # BR(B->X_s gamma)',
#  '     201    1.01342158E+00  # BR(B->X_s gamma)/BR(B->X_s gamma)_SM',
#  '     300    6.43937298E-04  # BR(D->mu nu)',
#  '     301    9.98913208E-01  # BR(D->mu nu)/BR(D->mu nu)_SM',
#  '     400    6.09405858E-03  # BR(Ds->mu nu)',
#  '     401    9.98787473E-01  # BR(Ds->mu nu)/BR(Ds->mu nu)_SM',
#  '     402    5.95524711E-02  # BR(Ds->tau nu)',
#  '     403    9.98787472E-01  # BR(Ds->tau nu)/BR(Ds->tau nu)_SM',
#  '     500    5.58644849E-07  # BR(B->mu nu)',
#  '     501    9.90556147E-01  # BR(B->mu nu)/BR(B->mu nu)_SM',
#  '     502    1.24306811E-04  # BR(B->tau nu)',
#  '     503    9.90556142E-01  # BR(B->tau nu)/BR(B->tau nu)_SM',
#  '     600    6.91538904E-01  # BR(K->mu nu)',
#  '     601    9.99917397E-01  # BR(K->mu nu)/BR(K->mu nu)_SM',
#  '     602    2.47647734E-05  # R_K = BR(K->e nu)/(K->mu nu)',
#  '     603    2.47606822E-05  # R_K^SM = BR(K->e nu)_SM/(K->mu nu)_SM',
#  '    1900    1.77959084E+01  # Delta(M_Bs)',
#  '    1901    1.00110510E+00  # Delta(M_Bs)/Delta(M_Bs)_SM',
#  '    1902    3.97842718E-01  # Delta(M_Bd)',
#  '    1903    1.00130376E+00  # Delta(M_Bd)/Delta(M_Bd)_SM',
#  '    4000    2.45475926E-15  # BR(B^0_d->e e)',
#  '    4001    9.99080421E-01  # BR(B^0_d->e e)/BR(B^0_d->e e)_SM',
#  '    4002    7.62205036E-14  # BR(B^0_s->e e)',
#  '    4003    9.99069582E-01  # BR(B^0_s->e e)/BR(B^0_s->e e)_SM',
#  '    4004    1.04864556E-10  # BR(B^0_d->mu mu)',
#  '    4005    9.99080441E-01  # BR(B^0_d->mu mu)/BR(B^0_d->mu mu)_SM',
#  '    4006    3.25613843E-09  # BR(B^0_s->mu mu)',
#  '    4007    9.99069603E-01  # BR(B^0_s->mu mu)/BR(B^0_s->mu mu)_SM',
#  '    4008    2.19496738E-08  # BR(B^0_d->tau tau)',
#  '    4009    9.99086248E-01  # BR(B^0_d->tau tau)/BR(B^0_d->tau tau)_SM',
#  '    4010    6.90574553E-07  # BR(B^0_s->tau tau)',
#  '    4011    9.99075606E-01  # BR(B^0_s->tau tau)/BR(B^0_s->tau tau)_SM',
#  '    5000    1.64028578E-06  # BR(B-> s e e)',
#  '    5001    9.90935592E-01  # BR(B-> s e e)/BR(B-> s e e)_SM',
#  '    5002    1.59012294E-06  # BR(B-> s mu mu)',
#  '    5003    9.90860448E-01  # BR(B-> s mu mu)/BR(B-> s mu mu)_SM',
#  '    6000    1.10802379E-07  # BR(B -> K mu mu)',
#  '    6001    9.98219628E-01  # BR(B -> K mu mu)/BR(B -> K mu mu)_SM',
#  '    6002    1.10802379E-07  # BR(B -> K mu mu)',
#  '    6003    9.98219628E-01  # BR(B -> K mu mu)/BR(B -> K mu mu)_SM',
#  '    7000    4.04970107E-05  # BR(B->s nu nu)',
#  '    7001    9.99805651E-01  # BR(B->s nu nu)/BR(B->s nu nu)_SM',
#  '    7002    1.87512012E-06  # BR(B->D nu nu)',
#  '    7003    9.99805340E-01  # BR(B->D nu nu)/BR(B->D nu nu)_SM',
#  '    8000    1.28895724E-10  # BR(K^+ -> pi^+ nu nu)',
#  '    8001    9.99883182E-01  # BR(K^+ -> pi^+ nu nu)/BR(K^+ -> pi^+ nu nu)_SM',
#  '    8002    2.99255432E-11  # BR(K_L -> pi^0 nu nu)',
#  '    8003    9.99800047E-01  # BR(K_L -> pi^0 nu nu)/BR(K_L -> pi^0 nu nu)_SM',
#  '    8004    0.00000000E+00  # BR(K^0_L -> e mu)',
#  '    8005    0.00000000E+00  # BR(K^0_L -> e mu)/BR(K^0_L -> e mu)_SM',
#  '    9100    1.94431073E-15  # Delta(M_K)',
#  '    9102    1.00000974E+00  # Delta(M_K)/Delta(M_K)_SM',
#  '    9103    1.84253115E-03  # epsilon_K',
#  '    9104    1.00107665E+00  # epsilon_K/epsilon_K^SM',
#  'Block FlavorKitLFV # lepton flavor violating observables ',
#  '     701    6.22440638E-34  # BR(mu->e gamma)',
#  '     702    0.00000000E+00  # BR(tau->e gamma)',
#  '     703    0.00000000E+00  # BR(tau->mu gamma)',
#  '     800    1.94745348E-36  # CR(mu-e, Al)',
#  '     801    3.50508072E-36  # CR(mu-e, Ti)',
#  '     802    4.74398544E-36  # CR(mu-e, Sr)',
#  '     803    5.33629446E-36  # CR(mu-e, Sb)',
#  '     804    2.87457065E-36  # CR(mu-e, Au)',
#  '     805    2.70390627E-36  # CR(mu-e, Pb)',
#  '     901    4.37579812E-36  # BR(mu->3e)',
#  '     902    0.00000000E+00  # BR(tau->3e)',
#  '     903    0.00000000E+00  # BR(tau->3mu)',
#  '     904    0.00000000E+00  # BR(tau- -> e- mu+ mu-)',
#  '     905    0.00000000E+00  # BR(tau- -> mu- e+ e-)',
#  '     906    0.00000000E+00  # BR(tau- -> e+ mu- mu-)',
#  '     907    0.00000000E+00  # BR(tau- -> mu+ e- e-)',
#  '    1001    1.38037059E-46  # BR(Z->e mu)',
#  '    1002    0.00000000E+00  # BR(Z->e tau)',
#  '    1003    0.00000000E+00  # BR(Z->mu tau)',
#  '    1101    7.53490099E-35  # BR(h->e mu)',
#  '    1102    0.00000000E+00  # BR(h->e tau)',
#  '    1103    0.00000000E+00  # BR(h->mu tau)',
#  '    2001    0.00000000E+00  # BR(tau->e pi)',
#  '    2002    0.00000000E+00  # BR(tau->e eta)',
#  "    2003    0.00000000E+00  # BR(tau->e eta')",
#  '    2004    0.00000000E+00  # BR(tau->mu pi)',
#  '    2005    0.00000000E+00  # BR(tau->mu eta)',
#  "    2006    0.00000000E+00  # BR(tau->mu eta')",
#  'Block FWCOEF Q=  1.60000000E+02  # Wilson coefficients at scale Q ',
#  '     0305 4422   00   0    -0.17093801E-08    # coeffC7sm',
#  '     0305 4422   00   2    -0.17450465E-08    # coeffC7',
#  '     0305 4322   00   2    -0.33590228E-10    # coeffC7p',
#  '     0305 4422   00   1    -0.35666463E-10    # coeffC7NP',
#  '     0305 4322   00   1    -0.33590228E-10    # coeffC7pNP',
#  '     0305 6421   00   0    -0.85541958E-09    # coeffC8sm',
#  '     0305 6421   00   2    -0.91802634E-09    # coeffC8',
#  '     0305 6321   00   2    -0.17667362E-10    # coeffC8p',
#  '     0305 6421   00   1    -0.62606760E-10    # coeffC8NP',
#  '     0305 6321   00   1    -0.17667362E-10    # coeffC8pNP',
#  ' 03051111 4133   00   0     0.10268343E-08    # coeffC9eeSM',
#  ' 03051111 4133   00   2     0.10267763E-08    # coeffC9ee',
#  ' 03051111 4233   00   2    -0.28224129E-14    # coeffC9Pee',
#  ' 03051111 4133   00   1    -0.58011779E-13    # coeffC9eeNP',
#  ' 03051111 4233   00   1    -0.28224129E-14    # coeffC9PeeNP',
#  ' 03051111 4137   00   0    -0.39233827E-08    # coeffC10eeSM',
#  ' 03051111 4137   00   2    -0.39228021E-08    # coeffC10ee',
#  ' 03051111 4237   00   2    -0.28523065E-13    # coeffC10Pee',
#  ' 03051111 4137   00   1     0.58061953E-12    # coeffC10eeNP',
#  ' 03051111 4237   00   1     0.28523065E-13    # coeffC10PeeNP',
#  ' 03051313 4133   00   0     0.10268338E-08    # coeffC9mumuSM',
#  ' 03051313 4133   00   2     0.10267757E-08    # coeffC9mumu',
#  ' 03051313 4233   00   2    -0.28224012E-14    # coeffC9Pmumu',
#  ' 03051313 4133   00   1    -0.58081074E-13    # coeffC9mumuNP',
#  ' 03051313 4233   00   1    -0.28224012E-14    # coeffC9PmumuNP',
#  ' 03051313 4137   00   0    -0.39233832E-08    # coeffC10mumuSM',
#  ' 03051313 4137   00   2    -0.39228027E-08    # coeffC10mumu',
#  ' 03051313 4237   00   2    -0.28523076E-13    # coeffC10Pmumu',
#  ' 03051313 4137   00   1     0.58055025E-12    # coeffC10mumuNP',
#  ' 03051313 4237   00   1    -0.28523076E-13    # coeffC10PmumuNP',
#  ' 03051212 4141   00   0    -0.12099200E-07    # coeffCLnu1nu1SM',
#  ' 03051212 4141   00   2    -0.12098040E-07    # coeffCLnu1nu1',
#  ' 03051212 4241   00   2     0.57046129E-13    # coeffCLPnu1nu1',
#  ' 03051212 4141   00   1     0.11599950E-11    # coeffCLnu1nu1NP',
#  ' 03051212 4241   00   1     0.57046129E-13    # coeffCLPnu1nu1NP',
#  ' 03051414 4141   00   0    -0.12099085E-07    # coeffCLnu2nu2SM',
#  ' 03051414 4141   00   2    -0.12097925E-07    # coeffCLnu2nu2',
#  ' 03051414 4241   00   2     0.57046106E-13    # coeffCLPnu2nu2',
#  ' 03051414 4141   00   1     0.11601717E-11    # coeffCLnu2nu2NP',
#  ' 03051414 4241   00   1     0.57046106E-13    # coeffCLPnu2nu2NP',
#  ' 03051616 4141   00   0    -0.12074599E-07    # coeffCLnu3nu3SM',
#  ' 03051616 4141   00   2    -0.12073389E-07    # coeffCLnu3nu3',
#  ' 03051616 4241   00   2     0.57039521E-13    # coeffCLPnu3nu3',
#  ' 03051616 4141   00   1     0.12103877E-11    # coeffCLnu3nu3NP',
#  ' 03051616 4241   00   1     0.57039521E-13    # coeffCLPnu3nu3NP',
#  ' 03051212 4142   00   0     0.00000000E+00    # coeffCRnu1nu1SM',
#  ' 03051212 4142   00   2     0.00000000E+00    # coeffCRnu1nu1',
#  ' 03051212 4242   00   2     0.00000000E+00    # coeffCRPnu1nu1',
#  ' 03051212 4142   00   1     0.00000000E+00    # coeffCRnu1nu1NP',
#  ' 03051212 4242   00   1     0.00000000E+00    # coeffCRPnu1nu1NP',
#  ' 03051414 4142   00   0     0.00000000E+00    # coeffCRnu2nu2SM',
#  ' 03051414 4142   00   2     0.00000000E+00    # coeffCRnu2nu2',
#  ' 03051414 4242   00   2     0.00000000E+00    # coeffCRPnu2nu2',
#  ' 03051414 4142   00   1     0.00000000E+00    # coeffCRnu2nu2NP',
#  ' 03051414 4242   00   1     0.00000000E+00    # coeffCRPnu2nu2NP',
#  ' 03051616 4142   00   0     0.00000000E+00    # coeffCRnu3nu3SM',
#  ' 03051616 4142   00   2     0.00000000E+00    # coeffCRnu3nu3',
#  ' 03051616 4242   00   2     0.00000000E+00    # coeffCRPnu3nu3',
#  ' 03051616 4142   00   1     0.00000000E+00    # coeffCRnu3nu3NP',
#  ' 03051616 4242   00   1     0.00000000E+00    # coeffCRPnu3nu3NP',
#  ' 01030103 3131   00   2    -0.18353589E-23    # coeffKK_SLL',
#  ' 01030103 3232   00   2    -0.66255322E-21    # coeffKK_SRR',
#  ' 01030103 3132   00   2    -0.93622916E-20    # coeffKK_SLR',
#  ' 01030103 4141   00   2     0.96136601E-13    # coeffKK_VLL',
#  ' 01030103 4242   00   2     0.14327556E-28    # coeffKK_VRR',
#  ' 01030103 4142   00   2    -0.34873702E-22    # coeffKK_VLR',
#  ' 01030103 4343   00   2    -0.91706669E-29    # coeffKK_TLL',
#  ' 01030103 4444   00   2    -0.33122738E-26    # coeffKK_TRR',
#  ' 01050105 3131   00   2    -0.96432564E-21    # coeffBB_SLL',
#  ' 01050105 3232   00   2    -0.94079996E-15    # coeffBB_SRR',
#  ' 01050105 3132   00   2    -0.10252470E-16    # coeffBB_SLR',
#  ' 01050105 4141   00   2     0.33307873E-11    # coeffBB_VLL',
#  ' 01050105 4242   00   2     0.40569673E-24    # coeffBB_VRR',
#  ' 01050105 4142   00   2    -0.95259227E-18    # coeffBB_VLR',
#  ' 01050105 4343   00   2    -0.55793439E-26    # coeffBB_TLL',
#  ' 01050105 4444   00   2    -0.70360610E-20    # coeffBB_TRR',
#  ' 03050305 3131   00   2    -0.10169586E-16    # coeffBsBs_SLL',
#  ' 03050305 3232   00   2    -0.27483820E-13    # coeffBsBs_SRR',
#  ' 03050305 3132   00   2    -0.56919932E-14    # coeffBsBs_SLR',
#  ' 03050305 4141   00   2     0.97316427E-10    # coeffBsBs_VLL',
#  ' 03050305 4242   00   2     0.42805788E-20    # coeffBsBs_VRR',
#  ' 03050305 4142   00   2    -0.52871987E-15    # coeffBsBs_VLR',
#  ' 03050305 4343   00   2    -0.58879102E-22    # coeffBsBs_TLL',
#  ' 03050305 4444   00   2    -0.20557598E-18    # coeffBsBs_TRR',
#  ' 01030103 3131   00   1     0.16330668E-25    # coeffKK_SLLNP',
#  ' 01030103 3232   00   1     0.58952775E-23    # coeffKK_SRRNP',
#  ' 01030103 3132   00   1    -0.83967310E-21    # coeffKK_SLRNP',
#  ' 01030103 4141   00   1     0.43106304E-17    # coeffKK_VLLNP',
#  ' 01030103 4242   00   1     0.23336380E-29    # coeffKK_VRRNP',
#  ' 01030103 4142   00   1     0.30809834E-24    # coeffKK_VLRNP',
#  ' 01030103 4343   00   1    -0.91706669E-29    # coeffKK_TLLNP',
#  ' 01030103 4444   00   1    -0.33122738E-26    # coeffKK_TRRNP',
#  ' 01050105 3131   00   1     0.94421705E-23    # coeffBB_SLLNP',
#  ' 01050105 3232   00   1     0.92182530E-17    # coeffBB_SRRNP',
#  ' 01050105 3132   00   1    -0.25786505E-17    # coeffBB_SLRNP',
#  ' 01050105 4141   00   1     0.26239187E-14    # coeffBB_VLLNP',
#  ' 01050105 4242   00   1     0.12104509E-24    # coeffBB_VRRNP',
#  ' 01050105 4142   00   1     0.92274369E-20    # coeffBB_VLRNP',
#  ' 01050105 4343   00   1    -0.55793439E-26    # coeffBB_TLLNP',
#  ' 01050105 4444   00   1    -0.70360610E-20    # coeffBB_TRRNP',
#  ' 03050305 3131   00   1     0.99572034E-19    # coeffBsBs_SLLNP',
#  ' 03050305 3232   00   1     0.26928607E-15    # coeffBsBs_SRRNP',
#  ' 03050305 3132   00   1    -0.14313560E-14    # coeffBsBs_SLRNP',
#  ' 03050305 4141   00   1     0.76649018E-13    # coeffBsBs_VLLNP',
#  ' 03050305 4242   00   1     0.12768501E-20    # coeffBsBs_VRRNP',
#  ' 03050305 4142   00   1     0.51350149E-17    # coeffBsBs_VLRNP',
#  ' 03050305 4343   00   1    -0.58879102E-22    # coeffBsBs_TLLNP',
#  ' 03050305 4444   00   1    -0.20557598E-18    # coeffBsBs_TRRNP',
#  ' 01030103 3131   00   0    -0.18516895E-23    # coeffKK_SLLSM',
#  ' 01030103 3232   00   0    -0.66844850E-21    # coeffKK_SRRSM',
#  ' 01030103 3132   00   0    -0.85226185E-20    # coeffKK_SLRSM',
#  ' 01030103 4141   00   0     0.96132291E-13    # coeffKK_VLLSM',
#  ' 01030103 4242   00   0     0.11993918E-28    # coeffKK_VRRSM',
#  ' 01030103 4142   00   0    -0.35181800E-22    # coeffKK_VLRSM',
#  ' 01030103 4343   00   0    -0.24093603E-46    # coeffKK_TLLSM',
#  ' 01030103 4444   00   0     0.29249818E-46    # coeffKK_TRRSM',
#  ' 01050105 3131   00   0    -0.97376781E-21    # coeffBB_SLLSM',
#  ' 01050105 3232   00   0    -0.95001822E-15    # coeffBB_SRRSM',
#  ' 01050105 3132   00   0    -0.76738190E-17    # coeffBB_SLRSM',
#  ' 01050105 4141   00   0     0.33281634E-11    # coeffBB_VLLSM',
#  ' 01050105 4242   00   0     0.28465164E-24    # coeffBB_VRRSM',
#  ' 01050105 4142   00   0    -0.96181971E-18    # coeffBB_VLRSM',
#  ' 01050105 4343   00   0     0.81931471E-55    # coeffBB_TLLSM',
#  ' 01050105 4444   00   0    -0.80542922E-49    # coeffBB_TRRSM',
#  ' 03050305 3131   00   0    -0.10269158E-16    # coeffBsBs_SLLSM',
#  ' 03050305 3232   00   0    -0.27753106E-13    # coeffBsBs_SRRSM',
#  ' 03050305 3132   00   0    -0.42606372E-14    # coeffBsBs_SLRSM',
#  ' 03050305 4141   00   0     0.97239778E-10    # coeffBsBs_VLLSM',
#  ' 03050305 4242   00   0     0.30037287E-20    # coeffBsBs_VRRSM',
#  ' 03050305 4142   00   0    -0.53385488E-15    # coeffBsBs_VLRSM',
#  ' 03050305 4343   00   0    -0.53694609E-50    # coeffBsBs_TLLSM',
#  ' 03050305 4444   00   0     0.30203596E-50    # coeffBsBs_TRRSM',
#  'Block IMFWCOEF Q=  1.60000000E+02  # Im(Wilson coefficients) at scale Q ',
#  '     0305 4422   00   0    -0.30508360E-10    # coeffC7sm',
#  '     0305 4422   00   2    -0.31144346E-10    # coeffC7',
#  '     0305 4322   00   2    -0.59948616E-12    # coeffC7p',
#  '     0305 4422   00   1    -0.63598599E-12    # coeffC7NP',
#  '     0305 4322   00   1    -0.59948616E-12    # coeffC7pNP',
#  '     0305 6421   00   0    -0.15268458E-10    # coeffC8sm',
#  '     0305 6421   00   2    -0.16385776E-10    # coeffC8',
#  '     0305 6321   00   2    -0.31533863E-12    # coeffC8p',
#  '     0305 6421   00   1    -0.11173183E-11    # coeffC8NP',
#  '     0305 6321   00   1    -0.31533863E-12    # coeffC8pNP',
#  ' 03051111 4133   00   0    -0.18334778E-10    # coeffC9eeSM',
#  ' 03051111 4133   00   2    -0.18333736E-10    # coeffC9ee',
#  ' 03051111 4233   00   2     0.50384102E-16    # coeffC9Pee',
#  ' 03051111 4133   00   1     0.10419574E-14    # coeffC9eeNP',
#  ' 03051111 4233   00   1     0.50384102E-16    # coeffC9PeeNP',
#  ' 03051111 4137   00   0     0.70017571E-10    # coeffC10eeSM',
#  ' 03051111 4137   00   2     0.70007207E-10    # coeffC10ee',
#  ' 03051111 4237   00   2     0.50917246E-15    # coeffC10Pee',
#  ' 03051111 4137   00   1    -0.10364279E-13    # coeffC10eeNP',
#  ' 03051111 4237   00   1    -0.50917246E-15    # coeffC10PeeNP',
#  ' 03051313 4133   00   0    -0.18334769E-10    # coeffC9mumuSM',
#  ' 03051313 4133   00   2    -0.18333726E-10    # coeffC9mumu',
#  ' 03051313 4233   00   2     0.50383893E-16    # coeffC9Pmumu',
#  ' 03051313 4133   00   1     0.10431941E-14    # coeffC9mumuNP',
#  ' 03051313 4233   00   1     0.50383893E-16    # coeffC9PmumuNP',
#  ' 03051313 4137   00   0     0.70017580E-10    # coeffC10mumuSM',
#  ' 03051313 4137   00   2     0.70007217E-10    # coeffC10mumu',
#  ' 03051313 4237   00   2     0.50917267E-15    # coeffC10Pmumu',
#  ' 03051313 4137   00   1    -0.10363043E-13    # coeffC10mumuNP',
#  ' 03051313 4237   00   1     0.50917267E-15    # coeffC10PmumuNP',
#  ' 03051212 4141   00   0     0.21598937E-09    # coeffCLnu1nu1SM',
#  ' 03051212 4141   00   2     0.21596867E-09    # coeffCLnu1nu1',
#  ' 03051212 4241   00   2    -0.10183467E-14    # coeffCLPnu1nu1',
#  ' 03051212 4141   00   1    -0.20707437E-13    # coeffCLnu1nu1NP',
#  ' 03051212 4241   00   1    -0.10183467E-14    # coeffCLPnu1nu1NP',
#  ' 03051414 4141   00   0     0.21598641E-09    # coeffCLnu2nu2SM',
#  ' 03051414 4141   00   2     0.21596570E-09    # coeffCLnu2nu2',
#  ' 03051414 4241   00   2    -0.10183462E-14    # coeffCLPnu2nu2',
#  ' 03051414 4141   00   1    -0.20710590E-13    # coeffCLnu2nu2NP',
#  ' 03051414 4241   00   1    -0.10183462E-14    # coeffCLPnu2nu2NP',
#  ' 03051616 4141   00   0     0.21552731E-09    # coeffCLnu3nu3SM',
#  ' 03051616 4141   00   2     0.21550570E-09    # coeffCLnu3nu3',
#  ' 03051616 4241   00   2    -0.10182290E-14    # coeffCLPnu3nu3',
#  ' 03051616 4141   00   1    -0.21606772E-13    # coeffCLnu3nu3NP',
#  ' 03051616 4241   00   1    -0.10182290E-14    # coeffCLPnu3nu3NP',
#  ' 03051212 4142   00   0     0.00000000E+00    # coeffCRnu1nu1SM',
#  ' 03051212 4142   00   2     0.00000000E+00    # coeffCRnu1nu1',
#  ' 03051212 4242   00   2     0.00000000E+00    # coeffCRPnu1nu1',
#  ' 03051212 4142   00   1     0.00000000E+00    # coeffCRnu1nu1NP',
#  ' 03051212 4242   00   1     0.00000000E+00    # coeffCRPnu1nu1NP',
#  ' 03051414 4142   00   0     0.00000000E+00    # coeffCRnu2nu2SM',
#  ' 03051414 4142   00   2     0.00000000E+00    # coeffCRnu2nu2',
#  ' 03051414 4242   00   2     0.00000000E+00    # coeffCRPnu2nu2',
#  ' 03051414 4142   00   1     0.00000000E+00    # coeffCRnu2nu2NP',
#  ' 03051414 4242   00   1     0.00000000E+00    # coeffCRPnu2nu2NP',
#  ' 03051616 4142   00   0     0.00000000E+00    # coeffCRnu3nu3SM',
#  ' 03051616 4142   00   2     0.00000000E+00    # coeffCRnu3nu3',
#  ' 03051616 4242   00   2     0.00000000E+00    # coeffCRPnu3nu3',
#  ' 03051616 4142   00   1     0.00000000E+00    # coeffCRnu3nu3NP',
#  ' 03051616 4242   00   1     0.00000000E+00    # coeffCRPnu3nu3NP',
#  ' 01030103 3131   00   2    -0.15910661E-23    # coeffKK_SLL',
#  ' 01030103 3232   00   2    -0.57436505E-21    # coeffKK_SRR',
#  ' 01030103 3132   00   2    -0.39425866E-21    # coeffKK_SLR',
#  ' 01030103 4141   00   2     0.61457943E-14    # coeffKK_VLL',
#  ' 01030103 4242   00   2     0.35788362E-30    # coeffKK_VRR',
#  ' 01030103 4142   00   2    -0.30232093E-22    # coeffKK_VLR',
#  ' 01030103 4343   00   2    -0.87803721E-29    # coeffKK_TLL',
#  ' 01030103 4444   00   2    -0.31654556E-26    # coeffKK_TRR',
#  ' 01050105 3131   00   2    -0.87165064E-21    # coeffBB_SLL',
#  ' 01050105 3232   00   2    -0.85038590E-15    # coeffBB_SRR',
#  ' 01050105 3132   00   2    -0.92719876E-17    # coeffBB_SLR',
#  ' 01050105 4141   00   2     0.30115617E-11    # coeffBB_VLL',
#  ' 01050105 4242   00   2     0.36710679E-24    # coeffBB_VRR',
#  ' 01050105 4142   00   2    -0.86095937E-18    # coeffBB_VLR',
#  ' 01050105 4343   00   2    -0.50569033E-26    # coeffBB_TLL',
#  ' 01050105 4444   00   2    -0.63640351E-20    # coeffBB_TRR',
#  ' 03050305 3131   00   2     0.36311339E-18    # coeffBsBs_SLL',
#  ' 03050305 3232   00   2     0.98133227E-15    # coeffBsBs_SRR',
#  ' 03050305 3132   00   2     0.20330523E-15    # coeffBsBs_SLR',
#  ' 03050305 4141   00   2    -0.34754123E-11    # coeffBsBs_VLL',
#  ' 03050305 4242   00   2    -0.15294886E-21    # coeffBsBs_VRR',
#  ' 03050305 4142   00   2     0.18876982E-16    # coeffBsBs_VLR',
#  ' 03050305 4343   00   2     0.21066065E-23    # coeffBsBs_TLL',
#  ' 03050305 4444   00   2     0.73439171E-20    # coeffBsBs_TRR',
#  ' 01030103 3131   00   1     0.15105079E-25    # coeffKK_SLLNP',
#  ' 01030103 3232   00   1     0.54528237E-23    # coeffKK_SRRNP',
#  ' 01030103 3132   00   1    -0.85924959E-22    # coeffKK_SLRNP',
#  ' 01030103 4141   00   1     0.41187250E-17    # coeffKK_VLLNP',
#  ' 01030103 4242   00   1     0.91349987E-31    # coeffKK_VRRNP',
#  ' 01030103 4142   00   1     0.28489818E-24    # coeffKK_VLRNP',
#  ' 01030103 4343   00   1    -0.87803721E-29    # coeffKK_TLLNP',
#  ' 01030103 4444   00   1    -0.31654556E-26    # coeffKK_TRRNP',
#  ' 01050105 3131   00   1     0.85341655E-23    # coeffBB_SLLNP',
#  ' 01050105 3232   00   1     0.83317444E-17    # coeffBB_SRRNP',
#  ' 01050105 3132   00   1    -0.23311198E-17    # coeffBB_SLRNP',
#  ' 01050105 4141   00   1     0.23714694E-14    # coeffBB_VLLNP',
#  ' 01050105 4242   00   1     0.10947406E-24    # coeffBB_VRRNP',
#  ' 01050105 4142   00   1     0.84256013E-20    # coeffBB_VLRNP',
#  ' 01050105 4343   00   1    -0.50569033E-26    # coeffBB_TLLNP',
#  ' 01050105 4444   00   1    -0.63640351E-20    # coeffBB_TRRNP',
#  ' 03050305 3131   00   1    -0.35551478E-20    # coeffBsBs_SLLNP',
#  ' 03050305 3232   00   1    -0.96146338E-17    # coeffBsBs_SRRNP',
#  ' 03050305 3132   00   1     0.51111770E-16    # coeffBsBs_SLRNP',
#  ' 03050305 4141   00   1    -0.27366069E-14    # coeffBsBs_VLLNP',
#  ' 03050305 4242   00   1    -0.45607868E-22    # coeffBsBs_VRRNP',
#  ' 03050305 4142   00   1    -0.18473533E-18    # coeffBsBs_VLRNP',
#  ' 03050305 4343   00   1     0.21066065E-23    # coeffBsBs_TLLNP',
#  ' 03050305 4444   00   1     0.73439171E-20    # coeffBsBs_TRRNP',
#  ' 01030103 3131   00   0    -0.16061712E-23    # coeffKK_SLLSM',
#  ' 01030103 3232   00   0    -0.57981788E-21    # coeffKK_SRRSM',
#  ' 01030103 3132   00   0    -0.30833370E-21    # coeffKK_SLRSM',
#  ' 01030103 4141   00   0     0.61416756E-14    # coeffKK_VLLSM',
#  ' 01030103 4242   00   0     0.26653363E-30    # coeffKK_VRRSM',
#  ' 01030103 4142   00   0    -0.30516991E-22    # coeffKK_VLRSM',
#  ' 01030103 4343   00   0    -0.51529086E-46    # coeffKK_TLLSM',
#  ' 01030103 4444   00   0    -0.71929865E-45    # coeffKK_TRRSM',
#  ' 01050105 3131   00   0    -0.88018481E-21    # coeffBB_SLLSM',
#  ' 01050105 3232   00   0    -0.85871765E-15    # coeffBB_SRRSM',
#  ' 01050105 3132   00   0    -0.69408679E-17    # coeffBB_SLRSM',
#  ' 01050105 4141   00   0     0.30091902E-11    # coeffBB_VLLSM',
#  ' 01050105 4242   00   0     0.25763273E-24    # coeffBB_VRRSM',
#  ' 01050105 4142   00   0    -0.86938497E-18    # coeffBB_VLRSM',
#  ' 01050105 4343   00   0     0.00000000E+00    # coeffBB_TLLSM',
#  ' 01050105 4444   00   0    -0.42956225E-49    # coeffBB_TRRSM',
#  ' 03050305 3131   00   0     0.36666854E-18    # coeffBsBs_SLLSM',
#  ' 03050305 3232   00   0     0.99094691E-15    # coeffBsBs_SRRSM',
#  ' 03050305 3132   00   0     0.15219346E-15    # coeffBsBs_SLRSM',
#  ' 03050305 4141   00   0    -0.34726757E-11    # coeffBsBs_VLLSM',
#  ' 03050305 4242   00   0    -0.10734100E-21    # coeffBsBs_VRRSM',
#  ' 03050305 4142   00   0     0.19061717E-16    # coeffBsBs_VLRSM',
#  ' 03050305 4343   00   0     0.00000000E+00    # coeffBsBs_TLLSM',
#  ' 03050305 4444   00   0     0.00000000E+00    # coeffBsBs_TRRSM',
#  'Block FineTuning #  ',
#  '       0    0.00000000E+00  #  Overall FT ',
#  '       1    0.00000000E+00  # m0',
#  '       2    0.00000000E+00  # m12',
#  '       3    0.00000000E+00  # Azero',
#  '       4    0.00000000E+00  # \\[Mu]',
#  '       5    0.00000000E+00  # B[\\[Mu]]',
#  'Block TREELEVELUNITARITY #  ',
#  '       0    1.00000000E+00  # Tree-level unitarity limits fulfilled or not ',
#  '       1    9.32973651E-03  # Maximal scattering eigenvalue ',
#  'Block TREELEVELUNITARITYwTRILINEARS #  ',
#  '       0    1.00000000E+00  # Tree-level unitarity limits fulfilled or not ',
#  '       1    7.61861203E-03  # Maximal scattering eigenvalue ',
#  '       2    3.00000000E+03  # best scattering energy ',
#  '      11    2.00000000E+03  # min scattering energy ',
#  '      12    3.00000000E+03  # max scattering energy ',
#  '      13    5.00000000E+00  # steps ',
#  'DECAY   1000001     4.98815071E+01   # Sd_1',
#  '#    BR                NDA      ID1      ID2',
#  '     2.81382733E-01    2            6   -1000024   # BR(Sd_1 -> Fu_3 Cha_1 )',
#  '     3.54392658E-01    2            6   -1000037   # BR(Sd_1 -> Fu_3 Cha_2 )',
#  '     9.31957765E-03    2            5    1000022   # BR(Sd_1 -> Fd_3 Chi_1 )',
#  '     1.39223348E-01    2            5    1000023   # BR(Sd_1 -> Fd_3 Chi_2 )',
#  '     4.35724091E-03    2            5    1000025   # BR(Sd_1 -> Fd_3 Chi_3 )',
#  '     7.17432602E-03    2            5    1000035   # BR(Sd_1 -> Fd_3 Chi_4 )',
#  '     2.04150116E-01    2      1000002        -24   # BR(Sd_1 -> Su_1 VWm )',
#  'DECAY   1000003     4.11872089E+00   # Sd_2',
#  '#    BR                NDA      ID1      ID2',
#  '     5.94303322E-02    2            6   -1000024   # BR(Sd_2 -> Fu_3 Cha_1 )',
#  '     2.98349933E-01    2            6   -1000037   # BR(Sd_2 -> Fu_3 Cha_2 )',
#  '     3.83363207E-01    2            5    1000022   # BR(Sd_2 -> Fd_3 Chi_1 )',
#  '     2.85429516E-02    2            5    1000023   # BR(Sd_2 -> Fd_3 Chi_2 )',
#  '     5.86960345E-02    2            5    1000025   # BR(Sd_2 -> Fd_3 Chi_3 )',
#  '     7.54359891E-02    2            5    1000035   # BR(Sd_2 -> Fd_3 Chi_4 )',
#  '     9.61815522E-02    2      1000002        -24   # BR(Sd_2 -> Su_1 VWm )',
#  'DECAY   1000005     1.64348911E+00   # Sd_3',
#  '#    BR                NDA      ID1      ID2',
#  '     9.99055191E-01    2            3    1000022   # BR(Sd_3 -> Fd_2 Chi_1 )',
#  '     1.10600697E-04    2            3    1000025   # BR(Sd_3 -> Fd_2 Chi_3 )',
#  '     6.47693551E-04    2            3    1000035   # BR(Sd_3 -> Fd_2 Chi_4 )',
#  'DECAY   2000001     1.64312670E+00   # Sd_4',
#  '#    BR                NDA      ID1      ID2',
#  '     9.99277046E-01    2            1    1000022   # BR(Sd_4 -> Fd_1 Chi_1 )',
#  '     6.02453383E-04    2            1    1000035   # BR(Sd_4 -> Fd_1 Chi_4 )',
#  'DECAY   2000003     2.63456670E+01   # Sd_5',
#  '#    BR                NDA      ID1      ID2',
#  '     6.31222299E-01    2            4   -1000024   # BR(Sd_5 -> Fu_2 Cha_1 )',
#  '     2.39890578E-02    2            4   -1000037   # BR(Sd_5 -> Fu_2 Cha_2 )',
#  '     1.72438239E-02    2            3    1000022   # BR(Sd_5 -> Fd_2 Chi_1 )',
#  '     3.16372391E-01    2            3    1000023   # BR(Sd_5 -> Fd_2 Chi_2 )',
#  '     1.10925240E-02    2            3    1000035   # BR(Sd_5 -> Fd_2 Chi_4 )',
#  'DECAY   2000005     2.63451222E+01   # Sd_6',
#  '#    BR                NDA      ID1      ID2',
#  '     6.31239314E-01    2            2   -1000024   # BR(Sd_6 -> Fu_1 Cha_1 )',
#  '     2.39742778E-02    2            2   -1000037   # BR(Sd_6 -> Fu_1 Cha_2 )',
#  '     1.72442533E-02    2            1    1000022   # BR(Sd_6 -> Fd_1 Chi_1 )',
#  '     3.16380627E-01    2            1    1000023   # BR(Sd_6 -> Fd_1 Chi_2 )',
#  '     1.10888230E-02    2            1    1000035   # BR(Sd_6 -> Fd_1 Chi_4 )',
#  'DECAY   1000002     2.50006527E+01   # Su_1',
#  '#    BR                NDA      ID1      ID2',
#  '     1.99215542E-01    2            6    1000022   # BR(Su_1 -> Fu_3 Chi_1 )',
#  '     2.81659075E-02    2            6    1000023   # BR(Su_1 -> Fu_3 Chi_2 )',
#  '     2.03653278E-01    2            6    1000025   # BR(Su_1 -> Fu_3 Chi_3 )',
#  '     1.62844905E-01    2            6    1000035   # BR(Su_1 -> Fu_3 Chi_4 )',
#  '     5.83567027E-02    2      1000024          5   # BR(Su_1 -> Cha_1^* Fd_3 )',
#  '     3.47763665E-01    2      1000037          5   # BR(Su_1 -> Cha_2^* Fd_3 )',
#  'DECAY   1000004     5.20409363E+01   # Su_2',
#  '#    BR                NDA      ID1      ID2',
#  '     9.10355269E-03    2            6    1000022   # BR(Su_2 -> Fu_3 Chi_1 )',
#  '     1.26452121E-01    2            6    1000023   # BR(Su_2 -> Fu_3 Chi_2 )',
#  '     1.72109217E-01    2            6    1000025   # BR(Su_2 -> Fu_3 Chi_3 )',
#  '     1.91933744E-01    2            6    1000035   # BR(Su_2 -> Fu_3 Chi_4 )',
#  '     2.49127384E-01    2      1000024          5   # BR(Su_2 -> Cha_1^* Fd_3 )',
#  '     3.90699788E-02    2      1000037          5   # BR(Su_2 -> Cha_2^* Fd_3 )',
#  '     1.02778100E-01    2      1000002         25   # BR(Su_2 -> Su_1 hh_1 )',
#  '     1.09425901E-01    2      1000002         23   # BR(Su_2 -> Su_1 VZ )',
#  'DECAY   1000006     6.63764455E+00   # Su_3',
#  '#    BR                NDA      ID1      ID2',
#  '     9.99150580E-01    2            4    1000022   # BR(Su_3 -> Fu_2 Chi_1 )',
#  ...]

# %%
len(SPheno_output.split('SPheno module generated by SARAH'))
# Out:
# 2136

# %%
AA = SPheno_output.split('SPheno module generated by SARAH')

# %%
for i in range(12,16):
    
    B = AA[i].split('DARKMATTER #')
    
    if len(B)==2:
        Omega = eval(AA[i].split('DARKMATTER #')[1].split()[1])
    
    else:
        Omega = -1.0
        
    print(i, Omega)
# Out:
# 12 -1.0
# 13 -1.0
# 14 0.286744
# 15 5.739619

# %% [markdown]
# the 15 has problems, because there is no Omega value

# %%
x=[]

NUM = len(SPheno_output.split('ENDOFPARAMETERPOINT'))

for i in range(1, NUM):
    
    
    B = AA[i].split('DARKMATTER #')
    
    if len(B)==2:
        Omega = eval(AA[i].split('DARKMATTER #')[1].split()[1])
    
    else:
        Omega = -1.0
    
    m0 = eval(AA[i].split('Block MINPAR  # Input parameters')[1].split()[1])
    m12 = eval(AA[i].split('Block MINPAR  # Input parameters')[1].split()[5])
    #print(i,Omega,m0,m12)
    
    x.append([Omega,m0,m12])

x=np.asarray(x)

xd=pd.DataFrame(x,columns=['Omega','m0','m12'])

# %%
xd[:3]
# Out:
#        Omega       m0      m12
# 0  -1.000000   354.60  1840.00
# 1  20.315536  1652.60   940.90
# 2  -1.000000   113.39   703.46

# %%
xd.shape
# Out:
# (2135, 3)

# %%
#For good plots
#plt.rcParams.update({'font.size': 20}) 
#plt.rc('font',size='18')

# %%
yd = xd[xd.Omega > 0.2]
wd = xd[np.logical_and(xd.Omega >0.0 , xd.Omega < 0.2)]

zd = xd[np.logical_and(xd.Omega >0.05 , xd.Omega < 0.15)]

CLSP = xd[xd.Omega < 0.0]

# %%
plt.figure(figsize=(6,5))

#plt.plot(xd.m0, xd.m12,'r.')
plt.plot(CLSP.m0, CLSP.m12,'r.', markersize=3, label='CLSP')
plt.plot(yd.m0, yd.m12,'y.', markersize=3, label='$\Omega > 0.2$')
plt.plot(wd.m0, wd.m12,'g.', markersize=4, label='$0.0 < \Omega < 0.2$')
plt.plot(zd.m0, zd.m12,'k.', markersize=4, label='$0.05 < \Omega < 0.15$')

plt.xlabel(r'$m_0$ (GeV)',size=12)
plt.ylabel(r'$M_{1/2}$ (GeV)',size=12)
plt.title('Only 2000 points with ML')
plt.legend()

#plt.tight_layout()

plt.show()

# %%
N = 1000
tiempo = 2000 

a=10000*(tiempo/N)*(1/3600)

print(a)
# Out:
# 5.555555555555555

# %%
a*
# Out:
# 13.375925925925923

# %%
plt.plot?
